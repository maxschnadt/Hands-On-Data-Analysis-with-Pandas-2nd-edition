# %%
import pandas as pd

df = pd.read_csv('data/parsed.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9332 entries, 0 to 9331
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   alert         59 non-null     object
#  1   cdi           329 non-null    float64
#  2   code          9332 non-null   object
#  3   detail        9332 non-null   object
#  4   dmin          6139 non-null   float64
#  5   felt          329 non-null    float64
#  6   gap           6164 non-null   float64
#  7   ids           9332 non-null   object
#  8   mag           9331 non-null   float64
#  9   magType       9331 non-null   object
#  10  mmi           93 non-null     float64
#  11  net           9332 non-null   object
#  12  nst           5364 non-null   float64
#  13  place         9332 non-null   object
#  14  rms           9332 non-null   float64
#  15  sig           9332 non-null   int64
#  16  sources       9332 non-null   object
#  17  status        9332 non-null   object
# ...

# %%
df[df.place.str.contains('Japan') & df.magType.str.contains('mb')].describe(percentiles=[0.05, 0.95])
# Out:
#              cdi       dmin       felt         gap        mag  mmi  nst  \
# count  16.000000  50.000000  16.000000   50.000000  50.000000  0.0  0.0
# mean    2.881250   1.485080  11.187500  108.880000   4.530000  NaN  NaN
# std     0.883341   0.802257  20.672748   31.676709   0.266688  NaN  NaN
# min     1.000000   0.223000   1.000000   33.000000   4.000000  NaN  NaN
# 5%      1.000000   0.533550   1.000000   68.700000   4.100000  NaN  NaN
# 50%     3.100000   1.271000   3.500000  112.000000   4.600000  NaN  NaN
# 95%     3.875000   2.583200  35.500000  155.650000   4.900000  NaN  NaN
# max     4.100000   4.830000  85.000000  167.000000   5.400000  NaN  NaN
#
#              rms         sig          time  tsunami          tz       updated
# count  50.000000   50.000000  5.000000e+01     50.0   50.000000  5.000000e+01
# mean    0.801800  318.080000  1.538218e+12      0.0  547.200000  1.538746e+12
# std     0.258589   38.570286  6.404535e+08      0.0   26.111222  5.518279e+08
# ...

# %%
df[df.place.str.contains('Indonesia') & df['tsunami']==1 & df.type.str.contains('earthquake')].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 285 entries, 262 to 9054
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   alert         10 non-null     object
#  1   cdi           9 non-null      float64
#  2   code          285 non-null    object
#  3   detail        285 non-null    object
#  4   dmin          190 non-null    float64
#  5   felt          9 non-null      float64
#  6   gap           193 non-null    float64
#  7   ids           285 non-null    object
#  8   mag           285 non-null    float64
#  9   magType       285 non-null    object
#  10  mmi           10 non-null     float64
#  11  net           285 non-null    object
#  12  nst           159 non-null    float64
#  13  place         285 non-null    object
#  14  rms           285 non-null    float64
#  15  sig           285 non-null    int64
#  16  sources       285 non-null    object
#  17  status        285 non-null    object
# ...

# %%
df[df.place.str.contains('Nevada')].describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  15.000000  677.000000  15.000000  677.000000  677.000000  1.00
# mean    2.440000    0.166982   2.400000  154.029527    0.491728  2.84
# std     0.501142    0.166400   4.626013   68.769713    0.689560   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.054000   1.000000   97.670000   -0.100000  2.84
# 50%     2.200000    0.113000   1.000000  149.550000    0.400000  2.84
# 75%     2.900000    0.234000   1.000000  200.470000    0.900000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  677.000000  677.000000  677.000000  6.770000e+02    677.0  677.0
# mean    12.608567    0.151909   10.688331  1.538314e+12      0.0 -480.0
# std      9.890620    0.084742   19.252727  5.954070e+08      0.0    0.0
# ...

# %%
labels = 'Alaska|Antarctic|Bolivia|California|Canada|Chile|Costa Rica|Ecuador|Fiji|Guatemala|Indonesia|Japan|Kermadec Islands|^Mexico|New Zealand|Peru|Philippines|Russia|Taiwan|Tonga|Washington'

# %%
df['ring_of_fire'] = df.parsed_place.str.contains(pat=labels, regex=True)

# %%
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
df[df.ring_of_fire & df.type.str.contains('earthquake')]
# Out:
#      alert  cdi      code                                             detail  \
# 0      NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1      NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2      NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3      NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4      NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...    ...  ...       ...                                                ...
# 9326   NaN  NaN  38063975  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9327   NaN  NaN  73086771  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9328   NaN  NaN  38063967  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9330   NaN  NaN  38063959  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9331   NaN  NaN  38063935  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
# ...

# %%
df[~df.ring_of_fire & df.type.str.contains('earthquake')]
# Out:
#      alert  cdi        code  \
# 5      NaN  NaN  2018286011
# 11     NaN  NaN  2018286010
# 17     NaN  NaN  2018286009
# 20     NaN  NaN  2018286008
# 30     NaN  NaN    80314224
# ...    ...  ...         ...
# 9306   NaN  NaN  2018261004
# 9307   NaN  NaN  2018261003
# 9315   NaN  NaN  2018261001
# 9319   NaN  NaN    2000hg5w
# 9329   NaN  NaN  2018261000
#
#                                                  detail    dmin  felt    gap  \
# 5     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.4373   NaN  158.0
# 11    https://earthquake.usgs.gov/fdsnws/event/1/que...  0.9477   NaN  186.0
# 17    https://earthquake.usgs.gov/fdsnws/event/1/que...  0.1061   NaN  145.0
# 20    https://earthquake.usgs.gov/fdsnws/event/1/que...  0.7059   NaN  294.0
# 30    https://earthquake.usgs.gov/fdsnws/event/1/que...  0.3020   NaN   88.0
# ...                                                 ...     ...   ...    ...
# 9306  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.7525   NaN  338.0
# ...

# %%
df[df.ring_of_fire & df.tsunami == 1]
# Out:
#       alert  cdi      code                                             detail  \
# 118   green  NaN  1000hbkz  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 799   green  NaN  1000hacw  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1015  green  NaN  20275238  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1273  green  NaN  20274320  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1406    NaN  NaN  1000h8zg  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1698    NaN  4.3  1000h8gb  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1795  green  3.1  20272669  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2414  green  3.8  73093981  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2752  green  NaN  20270862  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3112    NaN  NaN  1000h68e  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3150    NaN  NaN  1000h66t  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...
